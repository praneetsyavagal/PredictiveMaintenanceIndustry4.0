# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf 

tf.test.gpu_device_name()
# Out:
# ''

# %%
! pip install pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn import preprocessing
import io

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import io 
df2 = pd.read_csv('/content/drive/My Drive/sensor.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn import preprocessing

# %%
train_df = pd.read_csv('/content/drive/My Drive/sensor.csv', header=0)
train_df.drop(train_df.columns[[17]], axis=1, inplace=True)

# %%
train_df
# Out:
#         Unnamed: 0            timestamp  ...  sensor_51  machine_status
# 0                0  2018-04-01 00:00:00  ...   201.3889          NORMAL
# 1                1  2018-04-01 00:01:00  ...   201.3889          NORMAL
# 2                2  2018-04-01 00:02:00  ...   203.7037          NORMAL
# 3                3  2018-04-01 00:03:00  ...   203.1250          NORMAL
# 4                4  2018-04-01 00:04:00  ...   201.3889          NORMAL
# ...            ...                  ...  ...        ...             ...
# 220315      220315  2018-08-31 23:55:00  ...   231.1921          NORMAL
# 220316      220316  2018-08-31 23:56:00  ...   231.1921          NORMAL
# 220317      220317  2018-08-31 23:57:00  ...   232.0602          NORMAL
# 220318      220318  2018-08-31 23:58:00  ...   234.0856          NORMAL
# 220319      220319  2018-08-31 23:59:00  ...   234.0856          NORMAL
#
# [220320 rows x 54 columns]

# %%
'''
for i in range(2,54):
  #target = train_df[i]
  target = train_df.iloc[:, i]
  print(target)
  train_df = train_df.assign(InterpolateSLinear=train_df.target.interpolate(method='slinear'))
'''
train_df = train_df.interpolate(method ='linear', limit_direction ='forward') 
train_df['sensor_01'][27200]
#train_df[1]
# Out:
# 38.3680534362793

# %%
train_df.head()
# Out:
#    Unnamed: 0            timestamp  ...  sensor_51  machine_status
# 0           0  2018-04-01 00:00:00  ...   201.3889          NORMAL
# 1           1  2018-04-01 00:01:00  ...   201.3889          NORMAL
# 2           2  2018-04-01 00:02:00  ...   203.7037          NORMAL
# 3           3  2018-04-01 00:03:00  ...   203.1250          NORMAL
# 4           4  2018-04-01 00:04:00  ...   201.3889          NORMAL
#
# [5 rows x 54 columns]

# %%
k = 0
for i in range(len(train_df)):
    if(train_df["machine_status"][i] == "BROKEN"):
        print("Hi")
        count = 0
        for j in range(i,k-1,-1):
            train_df.at[j,'RUL']= count
            count = count + 1
        k = i
# Out:
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi

# %%
n = len(train_df)-1
while(train_df["machine_status"][n] != "BROKEN"):
    n -= 1   
train_df = train_df[:n+1]        
train_df["machine_status"][n+1] = 0

# %%
train_df
# Out:
#         Unnamed: 0            timestamp  ...  machine_status      RUL
# 0                0  2018-04-01 00:00:00  ...          NORMAL  17155.0
# 1                1  2018-04-01 00:01:00  ...          NORMAL  17154.0
# 2                2  2018-04-01 00:02:00  ...          NORMAL  17153.0
# 3                3  2018-04-01 00:03:00  ...          NORMAL  17152.0
# 4                4  2018-04-01 00:04:00  ...          NORMAL  17151.0
# ...            ...                  ...  ...             ...      ...
# 166436      166436  2018-07-25 13:56:00  ...          NORMAL      4.0
# 166437      166437  2018-07-25 13:57:00  ...          NORMAL      3.0
# 166438      166438  2018-07-25 13:58:00  ...          NORMAL      2.0
# 166439      166439  2018-07-25 13:59:00  ...          NORMAL      1.0
# 166440      166440  2018-07-25 14:00:00  ...          BROKEN      0.0
#
# [166441 rows x 55 columns]

# %%
train_df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
train_df.head()
# Out:
#              timestamp  sensor_00  sensor_01  ...  sensor_51  machine_status      RUL
# 0  2018-04-01 00:00:00   2.465394   47.09201  ...   201.3889          NORMAL  17155.0
# 1  2018-04-01 00:01:00   2.465394   47.09201  ...   201.3889          NORMAL  17154.0
# 2  2018-04-01 00:02:00   2.444734   47.35243  ...   203.7037          NORMAL  17153.0
# 3  2018-04-01 00:03:00   2.460474   47.09201  ...   203.1250          NORMAL  17152.0
# 4  2018-04-01 00:04:00   2.445718   47.13541  ...   201.3889          NORMAL  17151.0
#
# [5 rows x 54 columns]

# %%
train_df.drop(['machine_status'], axis=1, inplace=True)

# %%
train_df
# Out:
#                   timestamp  sensor_00  ...  sensor_51      RUL
# 0       2018-04-01 00:00:00   2.465394  ...   201.3889  17155.0
# 1       2018-04-01 00:01:00   2.465394  ...   201.3889  17154.0
# 2       2018-04-01 00:02:00   2.444734  ...   203.7037  17153.0
# 3       2018-04-01 00:03:00   2.460474  ...   203.1250  17152.0
# 4       2018-04-01 00:04:00   2.445718  ...   201.3889  17151.0
# ...                     ...        ...  ...        ...      ...
# 166436  2018-07-25 13:56:00   2.313889  ...   198.2060      4.0
# 166437  2018-07-25 13:57:00   2.315856  ...   202.8356      3.0
# 166438  2018-07-25 13:58:00   2.322743  ...   206.8866      2.0
# 166439  2018-07-25 13:59:00   2.315856  ...   209.7801      1.0
# 166440  2018-07-25 14:00:00   2.318808  ...   205.7292      0.0
#
# [166441 rows x 53 columns]

# %%
train_df.drop(['timestamp'], axis=1, inplace=True)
# from sklearn.decomposition import PCA

# train_df_pca = train_df
# print(train_df['RUL'])
# rul_pca = train_df_pca['RUL']
# print(rul_pca.head()) 
# train_df_pca.drop(['timestamp'], axis=1, inplace=True)
# #print(train_df_pca.head())
# train_df_pca.drop(['RUL'], axis=1, inplace=True)
# pca = PCA(n_components= 20)
# pca_data = pca.fit_transform(train_df_pca.values)
# print(pca_data[0])

# %%
len(train_df)
# Out:
# 166441

# %%
n_features = 51
n_steps = 10

# %%
# from sklearn.model_selection import train_test_split
# from numpy.random import seed
# Y = train_df['RUL']
# X = train_df.iloc[:, 0:51]
# X.head()
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = 0.6, random_state = seed(20))

# %%
# X_train.shape
# Out:
# (99864, 51)

# %%
# X_train= X_train.values.reshape(len(X_train), n_steps, n_features)
# X_test= X_test.values.reshape(len(X_test), n_steps, n_features)

# %%
# X_train.shape
# Out:
# (99864, 1, 51)

# %%
# from numpy import array
# from numpy import hstack
# from keras.models import Sequential
# from keras.layers import LSTM
# from keras.layers import Dense, Dropout
# from keras.optimizers import SGD
# from keras.layers import BatchNormalization
# from keras.regularizers import l1

# n_features = X_train.shape[2]
# # define model
# model = Sequential()
# model.add(LSTM(100, activation='relu', input_shape=(n_steps, n_features)))
# # model.add(LSTM(50, activation='relu'))
# model.add(Dense(1,activation='linear'))
# opt = SGD(lr=0.005, momentum=0.9, clipnorm=1.0, clipvalue=5.0)
# model.compile(loss='mean_squared_error', optimizer=opt)
# # model.compile(optimizer='adam', loss='mse',
#              # metrics=['accuracy'])
# # fit model
# model.fit(X_train, Y_train, epochs=10, verbose=1)
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-44dd5bb709f6> in <module>()
#       8 from keras.regularizers import l1
#       9
# ---> 10 n_features = X_train.shape[2]
#      11 # define model
#      12 model = Sequential()
#
# NameError: name 'X_train' is not defined

# %%
# multivariate data preparation
from numpy import array
from numpy import hstack

# split a multivariate sequence into samples
def split_sequences(sequences, n_steps):
	X, y = list(), list()
	for i in range(len(sequences)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the dataset
		if end_ix > len(sequences):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1, -1]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# define input sequence
#print(pca_data.shape)
#print(rul_pca.values.shape)
# rul_pca = rul_pca.values.reshape(220320,1)
dataset = train_df.values
# dataset = np.concatenate((pca_data,rul_pca),axis=1)
print('===================================',dataset)
# dataset2 = (dataset[~np.isnan(dataset).any(axis=1)])
#print(dataset)
# choose a number of time steps
n_steps = 10
# convert into input/output
X, y = split_sequences(dataset, n_steps)
#X, y = split_sequences(, n_steps)
print(X.shape, y.shape)
# summarize the data
# for i in range(len(X)):
# 	print(X[i], y[i])
# Out:
# =================================== [[2.46539400e+00 4.70920100e+01 5.32118000e+01 ... 2.43055600e+02
#   2.01388900e+02 1.71550000e+04]
#  [2.46539400e+00 4.70920100e+01 5.32118000e+01 ... 2.43055600e+02
#   2.01388900e+02 1.71540000e+04]
#  [2.44473400e+00 4.73524300e+01 5.32118000e+01 ... 2.41319400e+02
#   2.03703700e+02 1.71530000e+04]
#  ...
#  [2.32274300e+00 4.58333300e+01 5.29947900e+01 ... 1.00000000e+03
#   2.06886600e+02 2.00000000e+00]
#  [2.31585600e+00 4.57899300e+01 5.30381900e+01 ... 1.00000000e+03
#   2.09780100e+02 1.00000000e+00]
#  [2.31880800e+00 4.58333321e+01 5.29947900e+01 ... 1.00000000e+03
#   2.05729200e+02 0.00000000e+00]]
# (166432, 10, 51) (166432,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, train_size = 0.6, random_state = seed(20))
print(X_train)
print("=================================")
print(Y_train)
# Out:
# [[[2.49982600e+00 4.60503500e+01 5.32552100e+01 ... 6.10532400e+01
#    1.00000000e+03 1.84317100e+02]
#   [2.51064800e+00 4.60937500e+01 5.33854100e+01 ... 5.96064800e+01
#    1.00000000e+03 1.84027800e+02]
#   [2.49982600e+00 4.60937500e+01 5.33420100e+01 ... 5.81597214e+01
#    1.00000000e+03 1.83449100e+02]
#   ...
#   [2.51064800e+00 4.60503500e+01 5.33854100e+01 ... 5.26620400e+01
#    1.00000000e+03 1.75636600e+02]
#   [2.49982600e+00 4.61805500e+01 5.33854141e+01 ... 5.23726800e+01
#    1.00000000e+03 1.72453700e+02]
#   [2.51064800e+00 4.61805500e+01 5.33854100e+01 ... 5.17939800e+01
#    1.00000000e+03 1.68981500e+02]]
#
#  [[8.52297861e-02 3.95833321e+01 3.91493034e+01 ... 3.29861107e+01
#    3.38541679e+01 1.00000000e+03]
#   [8.52108451e-02 3.95833321e+01 3.91493034e+01 ... 3.29861107e+01
#    3.38541679e+01 1.00000000e+03]
#   [8.51919042e-02 3.95833300e+01 3.91493000e+01 ... 3.29861107e+01
#    3.38541679e+01 1.00000000e+03]
#   ...
# ...

# %%
from numpy import array
from numpy import hstack
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense, Dropout
from keras.optimizers import SGD
from keras.layers import BatchNormalization
from keras.regularizers import l1

n_features = X_train.shape[2]
# define model
model = Sequential()
model.add(LSTM(128, activation='relu', return_sequences=True, input_shape=(n_steps, n_features)))
model.add(LSTM(64, activation='relu'))
model.add(Dense(1,activation='linear'))
opt = SGD(lr=0.001, momentum=0.9, clipnorm=1.0, clipvalue=5.0)
model.compile(loss='mean_squared_error', optimizer=opt)
# model.compile(optimizer='adam', loss='mse',
             # metrics=['accuracy'])
# fit model
history = model.fit(X_train, Y_train, validation_split=0.25, epochs=100, verbose=1)
# demonstrate prediction
#yhat = model.predict(X_test, verbose=0)
#print(yhat)
# Out:
# Train on 74894 samples, validate on 24965 samples
# Epoch 1/100
# 74894/74894 [==============================] - 44s 589us/step - loss: 221990333.2462 - val_loss: 152956414.5234
# Epoch 2/100
# 74894/74894 [==============================] - 45s 596us/step - loss: 172136337.2459 - val_loss: 147105184.9960
# Epoch 3/100
# 74894/74894 [==============================] - 43s 580us/step - loss: 136876705.9981 - val_loss: 105746825.6455
# Epoch 4/100
# 74894/74894 [==============================] - 44s 581us/step - loss: 121313860.9410 - val_loss: 108855037.6941
# Epoch 5/100
# 74894/74894 [==============================] - 44s 584us/step - loss: 111514257.6275 - val_loss: 80072459.1612
# Epoch 6/100
# 74894/74894 [==============================] - 43s 572us/step - loss: 94572778.4273 - val_loss: 81202607.6405
# Epoch 7/100
# 74894/74894 [==============================] - 44s 583us/step - loss: 84276928.5207 - val_loss: 85873640.0535
# Epoch 8/100
# ...

# %%
y_pred = model.predict(X_test, verbose=0)

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-5b45066ea5d2> in <module>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.plot(history.history['val_acc'])
#       4 plt.title('Model accuracy')
#       5 plt.ylabel('Accuracy')
#
# KeyError: 'val_acc'

# %%
print(y_pred)
# Out:
# [[21838.836 ]
#  [26295.361 ]
#  [ 5915.1377]
#  ...
#  [25982.025 ]
#  [ 1844.6945]
#  [21930.49  ]]

# %%
print(Y_test)
# Out:
# [23527. 28063.  6607. ... 28939.  3257. 19258.]

# %%
from sklearn.metrics import r2_score
r2_score(Y_test, y_pred)
# Out:
# 0.9440189158992123

# %%
import pickle
from google.colab import files

# %%
filename = 'lstm_reg3_modelEPOCHS10.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
files.download('lstm_reg3_modelEPOCHS10.sav')

# %%
# multivariate multi-step stacked lstm example
from numpy import array
from numpy import hstack
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense, Dropout


n_features = X_train.shape[2]
# define model
model = Sequential()
model.add(LSTM(100, activation='relu', return_sequences=False, input_shape=(n_steps, n_features)))
model.add(Dense(100, activation='relu'))
model.add(Dense(1,kernel_initializer='normal',activation='relu'))
model.compile(optimizer='adam', loss='mse')
# fit model
history= model.fit(X_train, Y_train, validation_split=0.25, epochs=100, verbose=1)
# demonstrate prediction
yhat = model.predict(X_test, verbose=0)
print(yhat)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _get_default_graph()
#      65     try:
# ---> 66         return tf.get_default_graph()
#      67     except AttributeError:
#
# AttributeError: module 'tensorflow' has no attribute 'get_default_graph'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-60-ef5fb6649dbc> in <module>()
#       8 n_features = X_train.shape[2]
#       9 # define model
# ---> 10 model = Sequential()
#      11 model.add(LSTM(100, activation='relu', return_sequences=False, input_shape=(n_steps, n_features)))
#      12 model.add(Dense(100, activation='relu'))
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/sequential.py in __init__(self, layers, name)
# ...

# %%
Y_test

# %%
import pickle
from google.colab import files

# %%
filename = 'lstm_bin_modelEPOCH10.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
files.download('lstm_bin_modelEPOCH10.sav')
