# %%
import tensorflow as tf 
tf.test.gpu_device_name()
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# ''

# %%
! pip install pandas

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import io 
df2 = pd.read_csv('/content/drive/My Drive/sensor.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn import preprocessing

# %%
train_df = pd.read_csv('/content/drive/My Drive/sensor.csv', header=0)
train_df.drop(train_df.columns[[17]], axis=1, inplace=True)

# %%
train_df
# Out:
#         Unnamed: 0            timestamp  ...  sensor_51  machine_status
# 0                0  2018-04-01 00:00:00  ...   201.3889          NORMAL
# 1                1  2018-04-01 00:01:00  ...   201.3889          NORMAL
# 2                2  2018-04-01 00:02:00  ...   203.7037          NORMAL
# 3                3  2018-04-01 00:03:00  ...   203.1250          NORMAL
# 4                4  2018-04-01 00:04:00  ...   201.3889          NORMAL
# ...            ...                  ...  ...        ...             ...
# 220315      220315  2018-08-31 23:55:00  ...   231.1921          NORMAL
# 220316      220316  2018-08-31 23:56:00  ...   231.1921          NORMAL
# 220317      220317  2018-08-31 23:57:00  ...   232.0602          NORMAL
# 220318      220318  2018-08-31 23:58:00  ...   234.0856          NORMAL
# 220319      220319  2018-08-31 23:59:00  ...   234.0856          NORMAL
#
# [220320 rows x 54 columns]

# %%
'''
for i in range(2,54):
  #target = train_df[i]
  target = train_df.iloc[:, i]
  print(target)
  train_df = train_df.assign(InterpolateSLinear=train_df.target.interpolate(method='slinear'))
'''
train_df = train_df.interpolate(method ='slinear', limit_direction ='forward') 
train_df['sensor_01'][27200]
#train_df[1]
# Out:
# 38.3680534362793

# %%
train_df.head()
# Out:
#    Unnamed: 0            timestamp  ...  sensor_51  machine_status
# 0           0  2018-04-01 00:00:00  ...   201.3889          NORMAL
# 1           1  2018-04-01 00:01:00  ...   201.3889          NORMAL
# 2           2  2018-04-01 00:02:00  ...   203.7037          NORMAL
# 3           3  2018-04-01 00:03:00  ...   203.1250          NORMAL
# 4           4  2018-04-01 00:04:00  ...   201.3889          NORMAL
#
# [5 rows x 54 columns]

# %%
k = 0
for i in range(len(train_df)):
    if(train_df["machine_status"][i] == "BROKEN" or i==(len(train_df)-1)):
        print("Hi")
        count = 0
        for j in range(i,k-1,-1):
            train_df.at[j,'RUL']= count
            count = count + 1
        k = i
# Out:
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi

# %%
train_df
# Out:
#         Unnamed: 0            timestamp  ...  machine_status      RUL
# 0                0  2018-04-01 00:00:00  ...          NORMAL  17155.0
# 1                1  2018-04-01 00:01:00  ...          NORMAL  17154.0
# 2                2  2018-04-01 00:02:00  ...          NORMAL  17153.0
# 3                3  2018-04-01 00:03:00  ...          NORMAL  17152.0
# 4                4  2018-04-01 00:04:00  ...          NORMAL  17151.0
# ...            ...                  ...  ...             ...      ...
# 220315      220315  2018-08-31 23:55:00  ...          NORMAL      4.0
# 220316      220316  2018-08-31 23:56:00  ...          NORMAL      3.0
# 220317      220317  2018-08-31 23:57:00  ...          NORMAL      2.0
# 220318      220318  2018-08-31 23:58:00  ...          NORMAL      1.0
# 220319      220319  2018-08-31 23:59:00  ...          NORMAL      0.0
#
# [220320 rows x 55 columns]

# %%
train_df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
train_df.head()
# Out:
#              timestamp  sensor_00  sensor_01  ...  sensor_51  machine_status      RUL
# 0  2018-04-01 00:00:00   2.465394   47.09201  ...   201.3889          NORMAL  17155.0
# 1  2018-04-01 00:01:00   2.465394   47.09201  ...   201.3889          NORMAL  17154.0
# 2  2018-04-01 00:02:00   2.444734   47.35243  ...   203.7037          NORMAL  17153.0
# 3  2018-04-01 00:03:00   2.460474   47.09201  ...   203.1250          NORMAL  17152.0
# 4  2018-04-01 00:04:00   2.445718   47.13541  ...   201.3889          NORMAL  17151.0
#
# [5 rows x 54 columns]

# %%
train_df.drop(['machine_status'], axis=1, inplace=True)

# %%
for col in train_df.columns[1:-1]:
    train_df[col] = train_df[col].fillna(train_df[col].mean())

# %%
rul_csv = train_df.to_csv (r'rul_csv.csv', index = None, header=True)

# %%
train_df
# Out:
#                   timestamp  sensor_00  ...  sensor_51      RUL
# 0       2018-04-01 00:00:00   2.465394  ...   201.3889  17155.0
# 1       2018-04-01 00:01:00   2.465394  ...   201.3889  17154.0
# 2       2018-04-01 00:02:00   2.444734  ...   203.7037  17153.0
# 3       2018-04-01 00:03:00   2.460474  ...   203.1250  17152.0
# 4       2018-04-01 00:04:00   2.445718  ...   201.3889  17151.0
# ...                     ...        ...  ...        ...      ...
# 220315  2018-08-31 23:55:00   2.407350  ...   231.1921      4.0
# 220316  2018-08-31 23:56:00   2.400463  ...   231.1921      3.0
# 220317  2018-08-31 23:57:00   2.396528  ...   232.0602      2.0
# 220318  2018-08-31 23:58:00   2.406366  ...   234.0856      1.0
# 220319  2018-08-31 23:59:00   2.396528  ...   234.0856      0.0
#
# [220320 rows x 53 columns]

# %%
from sklearn.decomposition import PCA

train_df_pca = train_df
#train_df_pca.drop(['timestamp'], axis=1, inplace=True)
print(train_df_pca.head())
pca = PCA(n_components= 20)
arr = pca.fit_transform(train_df_pca.values)
print(len(arr[0]))
# Out:
#    sensor_00  sensor_01  sensor_02  ...  sensor_50  sensor_51      RUL
# 0   2.465394   47.09201    53.2118  ...   243.0556   201.3889  17155.0
# 1   2.465394   47.09201    53.2118  ...   243.0556   201.3889  17154.0
# 2   2.444734   47.35243    53.2118  ...   241.3194   203.7037  17153.0
# 3   2.460474   47.09201    53.1684  ...   240.4514   203.1250  17152.0
# 4   2.445718   47.13541    53.2118  ...   242.1875   201.3889  17151.0
#
# [5 rows x 52 columns]
# 20

# %%
from pandas import read_csv, DataFrame
from numpy.random import seed
from sklearn.preprocessing import minmax_scale
from sklearn.model_selection import train_test_split
from keras.layers import Input, Dense
from keras.models import Model
# Out:
# Using TensorFlow backend.

# %%
Y = train_df['RUL']
X = train_df.iloc[:, 1:52]
X.head()
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = 0.5, random_state = seed(2017))

# %%
X_test.head()
# Out:
#         sensor_01  sensor_02  sensor_03  ...   sensor_50  sensor_51      RUL
# 209220  49.522570   51.25868  45.789928  ...  183.046321   222.5116  11099.0
# 56475   47.526039   52.90799  44.531250  ...  187.210600   211.2269  12843.0
# 5395    48.567710   51.73611  44.661457  ...  258.680500   239.8727  11760.0
# 85784   49.913190   54.68750  44.531250  ...  250.578700   217.5926  42256.0
# 44522   46.614580   51.86632  43.185760  ...  184.317100   186.3426  24796.0
#
# [5 rows x 51 columns]

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
X = X_train
# y = 1 * x_0 + 2 * x_1 + 3
Y = Y_train
reg = LinearRegression().fit(X, Y)
reg.score(X, Y)

reg.coef_

reg.intercept_

# reg.predict(np.array([[3, 5]]))
# print(encoded_out,len(encoded_out))
# Out:
# -44131.44457449495

# %%
from sklearn.svm import SVR


regressor=SVR(kernel='linear',degree=1)
regressor.fit(X_train,Y_train)
pred=regressor.predict(xtest)



regressor=SVR(kernel='rbf',epsilon=1.0)
regressor.fit(X_train,Y_train)
pred=regressor.predict(xtest)

# %%
reg.predict(X_test)
# Out:
# array([ 9234.21657712,  9307.88275785, 24593.25165676, ...,
#        23169.99904847, 19597.94126743, 10064.73779967])

# %%
Y_test
# Out:
# 209220    11099.0
# 56475     12843.0
# 5395      11760.0
# 85784     42256.0
# 44522     24796.0
#            ...
# 135072     6059.0
# 18852      5658.0
# 44749     24569.0
# 145771    20669.0
# 62678      6640.0
# Name: RUL, Length: 110160, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(X)

X_train = []
y_train = []
for i in range(60, 2035):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

print(X_train)
# Out:
# [[[9.85719980e-01]
#   [9.63334871e-01]
#   [9.69509803e-01]
#   ...
#   [9.82246483e-01]
#   [9.84947917e-01]
#   [1.08173128e-02]]
#
#  [[9.63334871e-01]
#   [9.69509803e-01]
#   [9.62562809e-01]
#   ...
#   [9.84947917e-01]
#   [1.08173128e-02]
#   [9.18178230e-01]]
#
#  [[9.69509803e-01]
#   [9.62562809e-01]
#   [7.71902962e-04]
#   ...
#   [1.08173128e-02]
#   [9.18178230e-01]
#   [9.64878604e-01]]
#
#  ...
#
#  [[9.81088389e-01]
#   [9.73369332e-01]
#   [9.61019076e-01]
#   ...
#   [9.66422337e-01]
#   [9.79930687e-01]
#   [9.61405107e-01]]
#
#  [[9.73369332e-01]
#   [9.61019076e-01]
#   [9.81088389e-01]
#   ...
#   [9.79930687e-01]
#   [9.61405107e-01]
#   [9.76457190e-01]]
#
#  [[9.61019076e-01]
#   [9.81088389e-01]
#   [9.83790216e-01]
#   ...
#   [9.61405107e-01]
#   [9.76457190e-01]
#   [9.15476796e-01]]]

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

regressor = Sequential()

regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

regressor.add(Dense(units = 1))

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# ...

# %%
X_test.head()

# %%
dataset_total = pd.concat((X['sensor_00'], X_test['sensor_00']), axis = 0)
print(dataset_total)
inputs = dataset_total[len(dataset_total) - len(X) - 60:].values
inputs = inputs.reshape(-1,1)
#inputs = sc.transform(inputs)
X_test = []
for i in range(60, 76):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
#predicted_stock_price = sc.inverse_transform(predicted_stock_price)
print(predicted_stock_price)
